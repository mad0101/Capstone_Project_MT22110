# %% [markdown]
# <a href="https://colab.research.google.com/github/mad0101/Capstone_Project_MT22110/blob/main/YOLOV8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch

# %%
from IPython.display import Image

# %%
#!git clone https://github.com/ultralytics/yolov5

# %%
#%cd yolov5

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="HVuIFw2sixheKD61ArDb")
project = rf.workspace("indraprastha-institute-of-information-technology").project("mpl-0dnbp")
dataset = project.version(1).download("yolov8")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 2.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 9.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 24.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 19.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 7.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.0/69.0 kB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.8.1.78
#     Uninstalling opencv-python-headless-4.8.1.78:
# ...

# %%
root ='/content/MPL-1'

# %%
from tqdm import tqdm
# !pip install IProgress
from ipywidgets import IntProgress

# %%
torch.cuda.get_arch_list()
# Out:
# ['sm_37', 'sm_50', 'sm_60', 'sm_70', 'sm_75', 'sm_80', 'sm_86', 'sm_90']

# %%
print('All set. Using PyTorch version %s with %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# All set. Using PyTorch version 2.0.1+cu118 with _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15101MB, multi_processor_count=40)

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 618.9/618.9 kB 8.3 MB/s eta 0:00:00
# ...

# %%
import os
from ultralytics import YOLO

# Load a model
model = YOLO("yolov8n.yaml")

# Use the model
results = model.train(data = os.path.join(root, '/content/MPL-1/data.yaml'),epochs = 50) # Train the model.
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
#pip install -r requirements.txt

# %%
#!python train.py --img 640 --batch 16 --epochs 50 --data data.yaml --weights yolov5s.pt --cache
# Out:
# python3: can't open file '/content/train.py': [Errno 2] No such file or directory

# %%
#%load_ext tensorboard
#%tensorboard --logdir runs

# %%
Image(filename='/content/runs/detect/train2/val_batch0_labels.jpg', width=1000)

# %%
#!python export.py --weights runs/train/exp/weights/best.pt --include tflite --img 640

# %%
import subprocess
subprocess.run(['cp', '-r', '/content/runs', '/content/drive/MyDrive/Capstone/YOLOv8/50Epochs'])
# Out:
# CompletedProcess(args=['cp', '-r', '/content/runs', '/content/drive/MyDrive/Capstone/YOLOv8/50Epochs'], returncode=0)
